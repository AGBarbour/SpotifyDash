# %%
import requests
import json

# %%
access_token = "BQAjnAmKDb5PEwOij9wiay_27P_9CebDwlSRggJ2nt2Ny67rGVXTv0XEBjNt73vzqDKOc3kIpwnNajUTvNE_FQyBjmANg3GkfyT5_m6B4gn847Mezjvuk6oCloL18wl-Ot9omtMuWUCL2lJNilsEi7MA0D3rD6CIVjJKxGh3qwgSy1p29VNDIYAzGzoO1C_FNHdcuCHaBqpZC3kKJp4D3gFQtvDSgmTpK1du0etzJ0O-oI7Twv_qThzMGrFE6B9SRlTBA7u8Ipuieq1eGeo"

# %%
# time_range can be entered as "short", "medium", or "long"
def artist_search(time_range, access_token):
    
    artists = []
    
    #   Spotify API endpoint which returns users top artist for the specified time range
    endpoint = f"https://api.spotify.com/v1/me/top/artists?time_range={time_range}_term&limit=50"
    headers = {"Authorization": f"Bearer {access_token}"}

    response = requests.get(endpoint, headers=headers).json()
    
    items = response["items"]

    for item in items:

        genres = item["genres"]
        artist = item["name"]
        images = item["images"]
        artist_id = item["id"]
        popularity = item["popularity"]
        artist_url = item["external_urls"]["spotify"]
        followers = item["followers"]["total"]

        artists.append({
            "genres": genres,
            "artist": artist,
            "id": artist_id,
            "images": images,
            "popularity": popularity,
            "artist_url": artist_url,
            "followers": followers
        })

    return artists

# %%
# time_range can be entered as "short", "medium", or "long"
def track_search(time_range, access_token):
    
    tracks = []

    #   Spotify API endpoint which returns users top tracks for the specified time range
    endpoint = f"https://api.spotify.com/v1/me/top/tracks?time_range={time_range}_term&limit=50"
    headers = {"Authorization": f"Bearer {access_token}"}

    response = requests.get(endpoint, headers=headers).json()

    items = response["items"]

    for item in items:

        song = item["name"]
        artists = item["artists"][0]["name"]
        duration_ms = item["duration_ms"]
        song_id = item["id"]
        popularity = item["popularity"]
        preview_url = item["preview_url"]
        web_player_url = item["external_urls"]["spotify"]
        release_date = item["album"]["release_date"]
        release_date_precision = item["album"]["release_date_precision"]

        tracks.append({
            "song": song,
            "artists": artists,
            "id": song_id,
            "duration_ms": duration_ms,
            "popularity": popularity,
            "preview_url": preview_url,
            "web_player_url": web_player_url,
            "release_date": release_date,
            "release_date_precision": release_date_precision

        })
        
    return tracks

# %%
track_search("short", access_token)
# Out:
# [{'artists': 'Æther Realm',
#   'duration_ms': 1149621,
#   'id': '3pWYd7jexG4v82Tl4hC0qR',
#   'popularity': 26,
#   'preview_url': 'https://p.scdn.co/mp3-preview/67a3670b48ec72b95d17967e608dd40f4630826b?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2017-06-07',
#   'release_date_precision': 'day',
#   'song': 'The Sun, the Moon, the Star',
#   'web_player_url': 'https://open.spotify.com/track/3pWYd7jexG4v82Tl4hC0qR'},
#  {'artists': 'Æther Realm',
#   'duration_ms': 299056,
#   'id': '0z7wk0UN39Ad7vVznUQjfm',
#   'popularity': 30,
#   'preview_url': 'https://p.scdn.co/mp3-preview/aee327df97ba330b28f0a13283b84dc61823d9c8?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2017-06-07',
#   'release_date_precision': 'day',
#   'song': 'King of Cups (feat. Chris Bowes)',
#   'web_player_url': 'https://open.spotify.com/track/0z7wk0UN39Ad7vVznUQjfm'},
#  {'artists': 'Lil Yachty',
#   'duration_ms': 232320,
#   'id': '3UbBCQJ0SI9QDgtTY4lEHY',
#   'popularity': 56,
#   'preview_url': 'https://p.scdn.co/mp3-preview/8cb3622898c86844d8a9bde109b081067770205d?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2018-10-19',
#   'release_date_precision': 'day',
#   'song': 'We Outta Here! (feat. Young Nudy)',
#   'web_player_url': 'https://open.spotify.com/track/3UbBCQJ0SI9QDgtTY4lEHY'},
#  {'artists': 'Destiny Potato',
#   'duration_ms': 220071,
#   'id': '0jEySbb3DKhppgcE5sc03q',
#   'popularity': 44,
#   'preview_url': 'https://p.scdn.co/mp3-preview/e42c0bdecbeab2d0d8e9c0046e0574048b4c64e5?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2014-05-13',
#   'release_date_precision': 'day',
#   'song': 'Indifferent',
#   'web_player_url': 'https://open.spotify.com/track/0jEySbb3DKhppgcE5sc03q'},
#  {'artists': 'Jack The Joker',
#   'duration_ms': 1478329,
#   'id': '3VnrO2i3uFCkXE6n5ROvkR',
#   'popularity': 25,
#   'preview_url': 'https://p.scdn.co/mp3-preview/5d6cd6a8b7550a8e86389e9b06be7de860c7586b?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2016-11-23',
#   'release_date_precision': 'day',
#   'song': 'Venus & Mars',
#   'web_player_url': 'https://open.spotify.com/track/3VnrO2i3uFCkXE6n5ROvkR'},
#  {'artists': 'Infant Annihilator',
#   'duration_ms': 239696,
#   'id': '4vWB3h09KFwuS62Ex7NllR',
#   'popularity': 44,
#   'preview_url': 'https://p.scdn.co/mp3-preview/1f11e9278fad4eda8adb420070aed8ba109fca6e?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2016-07-29',
#   'release_date_precision': 'day',
#   'song': 'Soil the Stillborn',
#   'web_player_url': 'https://open.spotify.com/track/4vWB3h09KFwuS62Ex7NllR'},
#  {'artists': 'Everything Everything',
#   'duration_ms': 282853,
#   'id': '0bJKesHl9raebAYBpQp3wv',
#   'popularity': 34,
#   'preview_url': 'https://p.scdn.co/mp3-preview/7590897800818dbb131e90c463a829d4906f0c97?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2016-02-26',
#   'release_date_precision': 'day',
#   'song': 'No Reptiles',
#   'web_player_url': 'https://open.spotify.com/track/0bJKesHl9raebAYBpQp3wv'},
#  {'artists': 'Electric Guest',
#   'duration_ms': 217386,
#   'id': '6KwSdmAba8BxoxVXPw70LO',
#   'popularity': 57,
#   'preview_url': 'https://p.scdn.co/mp3-preview/c73d0d8e996b4916e3ca63b27374d59e4d78fd71?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2017-06-16',
#   'release_date_precision': 'day',
#   'song': 'Oh Devil - Radio Version',
#   'web_player_url': 'https://open.spotify.com/track/6KwSdmAba8BxoxVXPw70LO'},
#  {'artists': 'Veil Of Maya',
#   'duration_ms': 252906,
#   'id': '0nrCDNrt8fm5XJzu1FHudO',
#   'popularity': 48,
#   'preview_url': 'https://p.scdn.co/mp3-preview/4b2829773e85dde1da5e5874269b84fc179b4809?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2017-10-20',
#   'release_date_precision': 'day',
#   'song': 'Doublespeak',
#   'web_player_url': 'https://open.spotify.com/track/0nrCDNrt8fm5XJzu1FHudO'},
#  {'artists': 'Mire Lore',
#   'duration_ms': 533681,
#   'id': '00zG1mUt6aIl09XQlEOjLl',
#   'popularity': 18,
#   'preview_url': 'https://p.scdn.co/mp3-preview/b0f30da79fbce590e1df132592d81520cb5de2a3?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2018-07-30',
#   'release_date_precision': 'day',
#   'song': 'Return to the Abyss',
#   'web_player_url': 'https://open.spotify.com/track/00zG1mUt6aIl09XQlEOjLl'},
#  {'artists': 'Geek Music',
#   'duration_ms': 203255,
#   'id': '6oVlQDwNjuRx0LVKRV1gaQ',
#   'popularity': 57,
#   'preview_url': 'https://p.scdn.co/mp3-preview/971a1d89fc6d840359d347b81e3430025f8f75b1?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2018-11-28',
#   'release_date_precision': 'day',
#   'song': "Red Dead Redemption 2 - That's The Way It Is - Main Theme",
#   'web_player_url': 'https://open.spotify.com/track/6oVlQDwNjuRx0LVKRV1gaQ'},
#  {'artists': 'Two Door Cinema Club',
#   'duration_ms': 187720,
#   'id': '3kAwGo8mtUPsrctroxYLku',
#   'popularity': 57,
#   'preview_url': 'https://p.scdn.co/mp3-preview/33f4af2a98615a293f625119057fd8486a5a815f?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2012-01-01',
#   'release_date_precision': 'day',
#   'song': 'Sun',
#   'web_player_url': 'https://open.spotify.com/track/3kAwGo8mtUPsrctroxYLku'},
#  {'artists': 'Black Crown Initiate',
#   'duration_ms': 409826,
#   'id': '1JymMv5oG0QFAprNgJ3MQo',
#   'popularity': 32,
#   'preview_url': 'https://p.scdn.co/mp3-preview/cea24eb416530881898c44345aa669f3196f3aaa?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2014-09-30',
#   'release_date_precision': 'day',
#   'song': 'A Great Mistake',
#   'web_player_url': 'https://open.spotify.com/track/1JymMv5oG0QFAprNgJ3MQo'},
#  {'artists': 'Whitechapel',
#   'duration_ms': 304306,
#   'id': '0cPaBdPEXviKoAjcWJqI9M',
#   'popularity': 44,
#   'preview_url': 'https://p.scdn.co/mp3-preview/6092f5f53d603fa1bf2bbf5f46d810e24d814e4f?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2008-07-08',
#   'release_date_precision': 'day',
#   'song': 'Possession',
#   'web_player_url': 'https://open.spotify.com/track/0cPaBdPEXviKoAjcWJqI9M'},
#  {'artists': 'Disturbed',
#   'duration_ms': 248466,
#   'id': '1Cj2vqUwlJVG27gJrun92y',
#   'popularity': 74,
#   'preview_url': 'https://p.scdn.co/mp3-preview/27a108ea31c7a2e5b3622696d2cfe3885c59f913?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2015-08-21',
#   'release_date_precision': 'day',
#   'song': 'The Sound Of Silence',
#   'web_player_url': 'https://open.spotify.com/track/1Cj2vqUwlJVG27gJrun92y'},
#  {'artists': 'Cage The Elephant',
#   'duration_ms': 211373,
#   'id': '1Hb1IJ9bBCa6wo3fRtexnJ',
#   'popularity': 59,
#   'preview_url': 'https://p.scdn.co/mp3-preview/4156607e6ca4c66ad7403530a671faba4a88fecd?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2011-01-10',
#   'release_date_precision': 'day',
#   'song': 'Shake Me Down',
#   'web_player_url': 'https://open.spotify.com/track/1Hb1IJ9bBCa6wo3fRtexnJ'},
#  {'artists': 'Cage The Elephant',
#   'duration_ms': 214386,
#   'id': '1Q3t9fWvHUXKsMmpD2XpUu',
#   'popularity': 66,
#   'preview_url': 'https://p.scdn.co/mp3-preview/9b620191ec96b84e47bf572d43bd32a65316a9e2?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2015-12-18',
#   'release_date_precision': 'day',
#   'song': 'Cold Cold Cold',
#   'web_player_url': 'https://open.spotify.com/track/1Q3t9fWvHUXKsMmpD2XpUu'},
#  {'artists': 'Powerwolf',
#   'duration_ms': 230706,
#   'id': '20JQURYIb4mL30kr0rIloU',
#   'popularity': 51,
#   'preview_url': 'https://p.scdn.co/mp3-preview/51ab93f8bdb6f19d5155d529477a3a0ac4f4a16b?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2009',
#   'release_date_precision': 'year',
#   'song': 'Resurrection By Erection',
#   'web_player_url': 'https://open.spotify.com/track/20JQURYIb4mL30kr0rIloU'},
#  {'artists': 'Simon & Garfunkel',
#   'duration_ms': 185440,
#   'id': '2LkaNhCrNVmcYgXJeLVmsw',
#   'popularity': 68,
#   'preview_url': 'https://p.scdn.co/mp3-preview/173de2dea5dd26b7fdacec11d475b1a0e2d7d52c?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '1968-01-21',
#   'release_date_precision': 'day',
#   'song': 'The Sound of Silence',
#   'web_player_url': 'https://open.spotify.com/track/2LkaNhCrNVmcYgXJeLVmsw'},
#  {'artists': 'Two Door Cinema Club',
#   'duration_ms': 214253,
#   'id': '2Vfbf60Ujpom3Bcljzw7Dd',
#   'popularity': 7,
#   'preview_url': 'https://p.scdn.co/mp3-preview/ea4074b55119b7aa8cb0446b7abea4ecf9f60514?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2010-02-17',
#   'release_date_precision': 'day',
#   'song': 'Cigarettes In the Theatre',
#   'web_player_url': 'https://open.spotify.com/track/2Vfbf60Ujpom3Bcljzw7Dd'},
#  {'artists': 'Post Malone',
#   'duration_ms': 158040,
#   'id': '3KkXRkHbMCARz0aVfEt68P',
#   'popularity': 98,
#   'preview_url': 'https://p.scdn.co/mp3-preview/f2a0f4db4c1fc8e82ca34295eacf18c95f7de3e5?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2018-12-14',
#   'release_date_precision': 'day',
#   'song': 'Sunflower - Spider-Man: Into the Spider-Verse',
#   'web_player_url': 'https://open.spotify.com/track/3KkXRkHbMCARz0aVfEt68P'},
#  {'artists': 'Intervals',
#   'duration_ms': 261560,
#   'id': '3nDOvQvA8iPamdULGubIQE',
#   'popularity': 46,
#   'preview_url': 'https://p.scdn.co/mp3-preview/decb1007df2cb65e6db6184ee2b4d53b35675f51?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2017-12-01',
#   'release_date_precision': 'day',
#   'song': 'Touch and Go',
#   'web_player_url': 'https://open.spotify.com/track/3nDOvQvA8iPamdULGubIQE'},
#  {'artists': 'T.I.',
#   'duration_ms': 205360,
#   'id': '4XVfNwP88Hn9kSkXVnxj2S',
#   'popularity': 50,
#   'preview_url': 'https://p.scdn.co/mp3-preview/dcee964c9784d2393e7f3e395c5598024d200911?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2012-12-18',
#   'release_date_precision': 'day',
#   'song': 'Ball (feat. Lil Wayne)',
#   'web_player_url': 'https://open.spotify.com/track/4XVfNwP88Hn9kSkXVnxj2S'},
#  {'artists': 'Now, Now',
#   'duration_ms': 232360,
#   'id': '4pk6I8l87QhPwvWT5Wan0Q',
#   'popularity': 49,
#   'preview_url': 'https://p.scdn.co/mp3-preview/1f4f833c2b05dd868291a4ff4a3e13fde2ef99d0?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2018-05-18',
#   'release_date_precision': 'day',
#   'song': 'MJ',
#   'web_player_url': 'https://open.spotify.com/track/4pk6I8l87QhPwvWT5Wan0Q'},
#  {'artists': 'Cage The Elephant',
#   'duration_ms': 229346,
#   'id': '4sebUbjqbcgDSwG6PbSGI0',
#   'popularity': 64,
#   'preview_url': 'https://p.scdn.co/mp3-preview/496d73b9272a8d36ca974aaecc352f05cb90ea6a?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2013-10-08',
#   'release_date_precision': 'day',
#   'song': 'Come a Little Closer',
#   'web_player_url': 'https://open.spotify.com/track/4sebUbjqbcgDSwG6PbSGI0'},
#  {'artists': 'Vulfpeck',
#   'duration_ms': 183503,
#   'id': '58HemMGxAnAVkRMtzm7miy',
#   'popularity': 44,
#   'preview_url': 'https://p.scdn.co/mp3-preview/25d0e2885ecad1424db8cbcdb66469108d3d4f19?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2017-11-07',
#   'release_date_precision': 'day',
#   'song': 'Business Casual (feat. Coco O.)',
#   'web_player_url': 'https://open.spotify.com/track/58HemMGxAnAVkRMtzm7miy'},
#  {'artists': 'Alestorm',
#   'duration_ms': 202586,
#   'id': '5Hzto0vLxLb8GfkUtu6ZJK',
#   'popularity': 46,
#   'preview_url': 'https://p.scdn.co/mp3-preview/9664aa72ef1b91e07fb6965d75610bc3b4180327?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2014-08-05',
#   'release_date_precision': 'day',
#   'song': 'Drink',
#   'web_player_url': 'https://open.spotify.com/track/5Hzto0vLxLb8GfkUtu6ZJK'},
#  {'artists': 'Vulfpeck',
#   'duration_ms': 208954,
#   'id': '5KboIqx30dztT6wmEVFn17',
#   'popularity': 55,
#   'preview_url': 'https://p.scdn.co/mp3-preview/b9fc1f12150225376fa4a1c5bb1e0a16550f93d8?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2017-11-07',
#   'release_date_precision': 'day',
#   'song': 'Baby I Don’t Know Oh Oh (feat. Charles Jones)',
#   'web_player_url': 'https://open.spotify.com/track/5KboIqx30dztT6wmEVFn17'},
#  {'artists': 'Two Door Cinema Club',
#   'duration_ms': 177426,
#   'id': '5R34yWuK4EWjy3l6IAfMFJ',
#   'popularity': 8,
#   'preview_url': 'https://p.scdn.co/mp3-preview/80987b0436d7e634dfddcb22dda6cb7d6f046156?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2010-02-17',
#   'release_date_precision': 'day',
#   'song': 'I Can Talk',
#   'web_player_url': 'https://open.spotify.com/track/5R34yWuK4EWjy3l6IAfMFJ'},
#  {'artists': "D'Angelo",
#   'duration_ms': 232701,
#   'id': '5aozioXEMgxyttOvxCsckp',
#   'popularity': 64,
#   'preview_url': 'https://p.scdn.co/mp3-preview/1a07a59c153e801365814935382e7c32e26e11ff?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2019-01-04',
#   'release_date_precision': 'day',
#   'song': 'Unshaken',
#   'web_player_url': 'https://open.spotify.com/track/5aozioXEMgxyttOvxCsckp'},
#  {'artists': 'Everything Everything',
#   'duration_ms': 278226,
#   'id': '5kuLrW76C5MiGWKtgx098V',
#   'popularity': 33,
#   'preview_url': 'https://p.scdn.co/mp3-preview/e34da27a6dcc4faf4bb74ec7942e9ad9dcb7dff6?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2017-08-18',
#   'release_date_precision': 'day',
#   'song': 'Night Of The Long Knives',
#   'web_player_url': 'https://open.spotify.com/track/5kuLrW76C5MiGWKtgx098V'},
#  {'artists': 'Cage The Elephant',
#   'duration_ms': 225973,
#   'id': '5n0CTysih20NYdT2S0Wpe8',
#   'popularity': 69,
#   'preview_url': 'https://p.scdn.co/mp3-preview/809d189e8d99db8200488185750355465d6b64a5?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2015-12-18',
#   'release_date_precision': 'day',
#   'song': 'Trouble',
#   'web_player_url': 'https://open.spotify.com/track/5n0CTysih20NYdT2S0Wpe8'},
#  {'artists': 'Post Malone',
#   'duration_ms': 149520,
#   'id': '6MWtB6iiXyIwun0YzU6DFP',
#   'popularity': 97,
#   'preview_url': 'https://p.scdn.co/mp3-preview/c8de4be60dd5813f04d190223c2eceb7db9eccc8?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2018-12-24',
#   'release_date_precision': 'day',
#   'song': 'Wow.',
#   'web_player_url': 'https://open.spotify.com/track/6MWtB6iiXyIwun0YzU6DFP'},
#  {'artists': 'Geek Music',
#   'duration_ms': 213123,
#   'id': '6dIe57kvmP3K5JUs8CoQaC',
#   'popularity': 48,
#   'preview_url': 'https://p.scdn.co/mp3-preview/c1478d8e9bfe7b95ed438e440e5435941331c141?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2018-12-21',
#   'release_date_precision': 'day',
#   'song': 'Red Dead Redemption 2 - Cruel, Cruel World - Main Theme',
#   'web_player_url': 'https://open.spotify.com/track/6dIe57kvmP3K5JUs8CoQaC'},
#  {'artists': 'Post Malone',
#   'duration_ms': 231266,
#   'id': '7dt6x5M1jzdTEt8oCbisTK',
#   'popularity': 91,
#   'preview_url': 'https://p.scdn.co/mp3-preview/bb49bfad30f0729f70f8e9bd9c4ffb569c861698?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2018-04-27',
#   'release_date_precision': 'day',
#   'song': 'Better Now',
#   'web_player_url': 'https://open.spotify.com/track/7dt6x5M1jzdTEt8oCbisTK'},
#  {'artists': 'Gift Giver',
#   'duration_ms': 180213,
#   'id': '7yJQnCLLewENjWg8cWGDn4',
#   'popularity': 14,
#   'preview_url': 'https://p.scdn.co/mp3-preview/bef6616f42770c5d71f001ba03878c0f50038f36?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2013-02-14',
#   'release_date_precision': 'day',
#   'song': 'Daddy Issues',
#   'web_player_url': 'https://open.spotify.com/track/7yJQnCLLewENjWg8cWGDn4'},
#  {'artists': 'Lil Yachty',
#   'duration_ms': 158769,
#   'id': '3m2aDCqn8eT5ElXDUiboGU',
#   'popularity': 74,
#   'preview_url': 'https://p.scdn.co/mp3-preview/7b1e1d5c53727551fac3a9686234c3c4842ca4a7?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2018-10-19',
#   'release_date_precision': 'day',
#   'song': 'Get Dripped (feat. Playboi Carti)',
#   'web_player_url': 'https://open.spotify.com/track/3m2aDCqn8eT5ElXDUiboGU'},
#  {'artists': 'Cage The Elephant',
#   'duration_ms': 208760,
#   'id': '2tznHmp70DxMyr2XhWLOW0',
#   'popularity': 68,
#   'preview_url': 'https://p.scdn.co/mp3-preview/416309ca7cadf9255e07cfc054071ed9fade56d9?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2013-10-08',
#   'release_date_precision': 'day',
#   'song': 'Cigarette Daydreams',
#   'web_player_url': 'https://open.spotify.com/track/2tznHmp70DxMyr2XhWLOW0'},
#  {'artists': 'Erra',
#   'duration_ms': 282760,
#   'id': '4TrjswmJIALC9b8FgleAQN',
#   'popularity': 46,
#   'preview_url': 'https://p.scdn.co/mp3-preview/e935d960b569223d7a9b069ecbf8f5656b3cdf1f?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2018-08-10',
#   'release_date_precision': 'day',
#   'song': 'Breach',
#   'web_player_url': 'https://open.spotify.com/track/4TrjswmJIALC9b8FgleAQN'},
#  {'artists': 'Cage The Elephant',
#   'duration_ms': 177960,
#   'id': '00CqEmnPLFKDhAb3cuu6Cs',
#   'popularity': 51,
#   'preview_url': 'https://p.scdn.co/mp3-preview/1cbf1585793b4760ea7f34ceb30ed07b800840fc?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2013-10-08',
#   'release_date_precision': 'day',
#   'song': 'Halo',
#   'web_player_url': 'https://open.spotify.com/track/00CqEmnPLFKDhAb3cuu6Cs'},
#  {'artists': 'Two Door Cinema Club',
#   'duration_ms': 203960,
#   'id': '0b43NRSKWYa0P6R3dXaSlh',
#   'popularity': 8,
#   'preview_url': 'https://p.scdn.co/mp3-preview/0caf000eb99aaa290f0a1d1568c03b10b7a5076c?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2010-02-17',
#   'release_date_precision': 'day',
#   'song': 'Come Back Home',
#   'web_player_url': 'https://open.spotify.com/track/0b43NRSKWYa0P6R3dXaSlh'},
#  {'artists': 'Vulfpeck',
#   'duration_ms': 190801,
#   'id': '1SHA4IJyiyNobDOrQzFFXy',
#   'popularity': 56,
#   'preview_url': 'https://p.scdn.co/mp3-preview/29a5b5ddcbe54267a2711e42c662314e154a3a3f?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2016-10-17',
#   'release_date_precision': 'day',
#   'song': 'Animal Spirits',
#   'web_player_url': 'https://open.spotify.com/track/1SHA4IJyiyNobDOrQzFFXy'},
#  {'artists': 'Ariana Grande',
#   'duration_ms': 171573,
#   'id': '1TEL6MlSSVLSdhOSddidlJ',
#   'popularity': 83,
#   'preview_url': 'https://p.scdn.co/mp3-preview/d47136e51cc381cc0e30e6198528727237b76988?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2019-02-08',
#   'release_date_precision': 'day',
#   'song': 'needy',
#   'web_player_url': 'https://open.spotify.com/track/1TEL6MlSSVLSdhOSddidlJ'},
#  {'artists': 'Chaos Chaos',
#   'duration_ms': 150000,
#   'id': '29tzM8oIgOxBr3cI9CBOpb',
#   'popularity': 46,
#   'preview_url': 'https://p.scdn.co/mp3-preview/bbbecadcd05559aec8f27e446c167c8140ec10c7?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2017-08-27',
#   'release_date_precision': 'day',
#   'song': 'Terryfold',
#   'web_player_url': 'https://open.spotify.com/track/29tzM8oIgOxBr3cI9CBOpb'},
#  {'artists': 'Vulfpeck',
#   'duration_ms': 199639,
#   'id': '39rHfrVqCX6A55GF7uOZSC',
#   'popularity': 57,
#   'preview_url': 'https://p.scdn.co/mp3-preview/ac2e0daf53d6b58ec897468d67b0b59f7ea903b6?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2014-08-26',
#   'release_date_precision': 'day',
#   'song': '1612',
#   'web_player_url': 'https://open.spotify.com/track/39rHfrVqCX6A55GF7uOZSC'},
#  {'artists': 'Vulfpeck',
#   'duration_ms': 230676,
#   'id': '48wH8bAxvBJO2l14GmNLz7',
#   'popularity': 59,
#   'preview_url': 'https://p.scdn.co/mp3-preview/cf3243369a3ace437df5e681220f5af4c7763c68?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2013-12-06',
#   'release_date_precision': 'day',
#   'song': 'Wait for the Moment',
#   'web_player_url': 'https://open.spotify.com/track/48wH8bAxvBJO2l14GmNLz7'},
#  {'artists': 'Æther Realm',
#   'duration_ms': 370615,
#   'id': '5LxOPRsUc9ikcRsOZ0P54x',
#   'popularity': 28,
#   'preview_url': 'https://p.scdn.co/mp3-preview/0609f3a315739c35121a84677e7dab7273a525f7?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2013-12-01',
#   'release_date_precision': 'day',
#   'song': 'The Magician',
#   'web_player_url': 'https://open.spotify.com/track/5LxOPRsUc9ikcRsOZ0P54x'},
#  {'artists': 'Cage The Elephant',
#   'duration_ms': 222813,
#   'id': '5r5Lj2MkgwQJz6TaBdL865',
#   'popularity': 53,
#   'preview_url': 'https://p.scdn.co/mp3-preview/06d51ab0dc2ad4ef2442f1492e24cf7a0004e123?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2013-10-08',
#   'release_date_precision': 'day',
#   'song': 'Spiderhead',
#   'web_player_url': 'https://open.spotify.com/track/5r5Lj2MkgwQJz6TaBdL865'},
#  {'artists': 'Acrania',
#   'duration_ms': 173250,
#   'id': '6MD1hqDCJMxP8fbHVGifEB',
#   'popularity': 39,
#   'preview_url': 'https://p.scdn.co/mp3-preview/1ff773ab810ddde2df261d1a9a9799ccb868f1c2?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2014-08-19',
#   'release_date_precision': 'day',
#   'song': 'Disillusion in a Discordant System',
#   'web_player_url': 'https://open.spotify.com/track/6MD1hqDCJMxP8fbHVGifEB'},
#  {'artists': 'Veil Of Maya',
#   'duration_ms': 207760,
#   'id': '6xsebzD3CmhP5c51FZFZRB',
#   'popularity': 44,
#   'preview_url': 'https://p.scdn.co/mp3-preview/9eafa3a45b02af75f18b986df25678c63556bc14?cid=774b29d4f13844c495f206cafdad9c86',
#   'release_date': '2017-10-20',
#   'release_date_precision': 'day',
#   'song': 'Whistleblower',
#   'web_player_url': 'https://open.spotify.com/track/6xsebzD3CmhP5c51FZFZRB'}]
